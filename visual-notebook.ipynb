# %%
from utils import get_service_ip, display_page

# %%
ip = get_service_ip('mynginx')
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-4-6b2e86fd4fb2> in <module>()
# ----> 1 ip = get_service_ip('mynginx')
#
# ~/kubernetes-scotlandphp/utils.py in get_service_ip(service)
#      11     v1Api = client.CoreV1Api()
#      12     result = v1Api.list_namespaced_endpoints(ns)
# ---> 13     item = next(i for i in result.items if i.metadata.name == service)
#      14     return item.subsets[0].addresses[0].ip
#      15
#
# StopIteration:

# %%
display_page('http://' + ip + '/')
# Out:
# <iframe style="width: 100%; height: 500px" src="data:text/html;base64,..."></iframe>

# %% [markdown]
# # Wordpress

# %%
from utils import get_service_ip, display_page
ip = get_service_ip('mywordpress-lamp')
display_page('http://' + ip + '/')
# Out:
# <iframe style="width: 100%; height: 500px" src="data:text/html;base64,..."></iframe>

# %% [markdown]
# # Laravel

# %%
from utils import get_service_ip, display_page
ip = get_service_ip('buckram-laravel-nginx')
display_page('http://' + ip + '/')
# Out:
# <iframe style="width: 100%; height: 500px" src="data:text/html;base64,..."></iframe>
